# %% [markdown]
# #### 1. Create three variables in Python: user_name, fav_app, and daily_usage_hours. Assign your own name, your favorite app (like Instagram or Zomato), and how many hours you use it daily.

# %%
user_name = "Mudra"
fav_app = "Linkdein"
hours = 4

# %%
print("User name:",user_name)
print("Favourite app:",fav_app)
print("Hours of usage:", hours)
# Out:
# User name: Mudra
# Favourite app: Linkdein
# Hours of usage: 4

# %% [markdown]
# #### 2. Write a Python script that declares variables for product_name, price, and is_available to represent an item on Flipkart. Print each variable and its data type using the type() function.

# %%
product_name = "Polo Tshirt"
price = 1599
is_available = True

print("Product Name:", product_name)
print("Data type of the variable:",type(product_name))

print("\nPrice of the Product:",price)
print("Data type of the Variable:",type(price))

print("\nAn item on flipkart:",is_available)
print("Data type of the Variable:",type(is_available))
# Out:
# Product Name: Polo Tshirt
# Data type of the variable: <class 'str'>
#
# Price of the Product: 1599
# Data type of the Variable: <class 'int'>
#
# An item on flipkart: True
# Data type of the Variable: <class 'bool'>

# %% [markdown]
# #### 3. Demonstrate the difference between single-line and multi-line comments in Python by writing a script that explains how a Spotify playlist recommendation system might work. Use # for single-line and triple quotes for multi-line comments.

# %%
# Writing a script that explains how a Spotify playlist recommendation system might work.

"""
A Spotify playlist recommendation system uses three main pillars—collaborative filtering, content-based filtering,
and NLP—to analyze your listening habits. By comparing your playlist's audio data and artist vectors to millions of other users' patterns,
 the algorithm curates personalized song suggestions.
"""
# Out:
# "\nA Spotify playlist recommendation system uses three main pillars—collaborative filtering, content-based filtering,\nand NLP—to analyze your listening habits. By comparing your playlist's audio data and artist vectors to millions of other users' patterns,\n the algorithm curates personalized song suggestions.\n"

# %% [markdown]
# #### 4. Create variables for order_total, delivery_region, and discount_percent to represent a Zomato order. Follow Python naming conventions and print a sentence using all three variables, like 'Order from [region] totals ₹[order_total] with [discount_percent]% discount.'

# %%
Order_total = 2500
Delivery_region = "Naroda"
Discount_percent = 20.00

print("Order from ",Delivery_region,"totals ₹",Order_total,"with",Discount_percent,"% dicount")
# Out:
# Order from  Naroda totals ₹ 2500 with 20.0 % dicount

# %% [markdown]
# #### 5. Write a Python script that intentionally mixes tabs and spaces for indentation, then fix the script so it runs without errors.<br><br><em><strong>Hint:</strong> Use only spaces for indentation, as per Python's best practices.</em>

# %%
if b>2:
print(a)
# Out:
#   Cell In[7], line 2
#     print(a)
#     ^
# IndentationError: expected an indented block after 'if' statement on line 1
