# %%
print("Mudra Patel")
# Out:
# Mudra Patel

# %%
print("My favourite app is linkedin")
# Out:
# My favourite app is linkedin

# %%
print("Welcome to Data Analytics with Python!")
# Out:
# Welcome to Data Analytics with Python!

# %%
import datetime

# %%
print(datetime.datetime.now())
# Out:
# 2026-06-09 09:43:01.542263
