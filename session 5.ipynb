# %% [markdown]
# #### 1. Create a list called playlist_ids with 5 integers representing Spotify playlist IDs, then use append() to add a new playlist ID at the end and print the updated list.

# %%
playlist_ids = ["Arijit Singh","armaan Malik","Tulsi Kumar","vishal Mishra","Darshan Raval"]
print(playlist_ids)

playlist_ids.append("Sunidhi Chauhan")

print("\nUpdated List:",playlist_ids)
# Out:
# ['Arijit Singh', 'armaan Malik', 'Tulsi Kumar', 'vishal Mishra', 'Darshan Raval']
#
# Updated List: ['Arijit Singh', 'armaan Malik', 'Tulsi Kumar', 'vishal Mishra', 'Darshan Raval', 'Sunidhi Chauhan']

# %% [markdown]
# #### 2. Simulate a Flipkart shopping cart: start with a list cart_items containing 't-shirt', 'shoes'. Use extend() to add ['jeans', 'cap'] to the cart, then print the final list of items.

# %%
cart_item = ["t-shirt","shoes"]
print(cart_item)

cart_item.extend("jeans")
cart_item.extend("cap")

print("\nFinal List:",cart_item )
# Out:
# ['t-shirt', 'shoes']
#
# Final List: ['t-shirt', 'shoes', 'j', 'e', 'a', 'n', 's', 'c', 'a', 'p']

# %% [markdown]
# #### 3. Write a function remove_last_item(order_list) that pops the last item from a Zomato order list and returns the removed item. Test it with a sample order_list.

# %%
order = ["rice","dal","roti","subji"]
print("Your zomato Order:",order)

order.pop()
print(order)
# Out:
# Your zomato Order: ['rice', 'dal', 'roti', 'subji']
# ['rice', 'dal', 'roti']

# %% [markdown]
# #### 4. Create a tuple called insta_filters with 4 Instagram filter names. Try to update the second filter and observe what error you get. Explain in a comment why this happens.<br><br><em><strong>Hint:</strong> Tuples are immutable, so direct assignment won't work.</em>

# %%
filters = ("Red","White","Black","yellow")
print(filters)
filters.update("White","Blue")

# tuples are immutable. so you cannot add, replace or modify any item from the tuple.
# Out:
# ('Red', 'White', 'Black', 'yellow')
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[7], line 3
#       1 filters = ("Red","White","Black","yellow")
#       2 print(filters)
# ----> 3 filters.update("White","Blue")
#       5 # tuples are immutable. so you cannot add, replace or modify any item from the tuple.
#
# AttributeError: 'tuple' object has no attribute 'update'

# %% [markdown]
# #### 5. Given two scenarios — storing a user's favorite genres (which may change) and storing a fixed set of IRCTC train classes ('Sleeper', 'AC 3 Tier', 'AC 2 Tier') — choose whether to use a list or tuple for each. Write one sentence explaining your choice for both.

# %%
tuple = ('Sleeper', 'AC 3 Tier', 'AC 2 Tier')
print(tuple)
print("Used tuple for the IRCTC train classes because the reservations are fixed. so for fixed values we use tuple.")

genres = ["happy","sad","trending"]
print("\n",genres)
print("Used list for the user's favorite genres beacuse users choice of genres can change. so for changable values we use list.")
# Out:
# ('Sleeper', 'AC 3 Tier', 'AC 2 Tier')
# Used tuple for the IRCTC train classes because the reservations are fixed. so for fixed values we use tuple.
#
#  ['happy', 'sad', 'trending']
# Used list for the user's favorite genres beacuse users choice of genres can change. so for changable values we use list.
